# %%
import pandas as pd

# %%
raw_movie_data = pd.read_json("movies.json")

# %%
raw_movie_data
# Out:
#                         title  year  rating                          genres
# 0    The Shawshank Redemption  1994     9.3                         [Drama]  \
# 1               The Godfather  1972     9.2                  [Crime, Drama]
# 2             The Chaos Class  1975     9.2                 [Comedy, Drama]
# 3             The Dark Knight  2008     9.0          [Action, Crime, Drama]
# 4            Schindler's List  1993     9.0     [Biography, Drama, History]
# ..                        ...   ...     ...                             ...
# 995            Train to Busan  2016     7.6      [Action, Horror, Thriller]
# 996             Moulin Rouge!  2001     7.6       [Drama, Musical, Romance]
# 997             Incredibles 2  2018     7.6  [Animation, Action, Adventure]
# 998  The Peanut Butter Falcon  2019     7.6      [Adventure, Comedy, Drama]
# 999             Kung Fu Panda  2008     7.6  [Animation, Action, Adventure]
#
#      runtime    votes
# 0        142  2743383
# ...

# %%
movies = raw_movie_data.copy()

# %%
movies
# Out:
#                         title  year  rating                          genres
# 0    The Shawshank Redemption  1994     9.3                         [Drama]  \
# 1               The Godfather  1972     9.2                  [Crime, Drama]
# 2             The Chaos Class  1975     9.2                 [Comedy, Drama]
# 3             The Dark Knight  2008     9.0          [Action, Crime, Drama]
# 4            Schindler's List  1993     9.0     [Biography, Drama, History]
# ..                        ...   ...     ...                             ...
# 995            Train to Busan  2016     7.6      [Action, Horror, Thriller]
# 996             Moulin Rouge!  2001     7.6       [Drama, Musical, Romance]
# 997             Incredibles 2  2018     7.6  [Animation, Action, Adventure]
# 998  The Peanut Butter Falcon  2019     7.6      [Adventure, Comedy, Drama]
# 999             Kung Fu Panda  2008     7.6  [Animation, Action, Adventure]
#
#      runtime    votes
# 0        142  2743383
# ...
