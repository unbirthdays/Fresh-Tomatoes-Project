# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.stats import pearsonr, spearmanr

# %%
raw_movie_data = pd.read_json("movielist.json")

# %%
raw_movie_data
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                           genres  runtime    votes  metascore
# 0                        [Drama]      142  2757059       82.0
# 1                 [Crime, Drama]      175  1918435      100.0
# 2                [Comedy, Drama]       87    41819        NaN
# ...

# %%
movies = raw_movie_data.copy()

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                           genres  runtime    votes  metascore
# 0                        [Drama]      142  2757059       82.0
# 1                 [Crime, Drama]      175  1918435      100.0
# 2                [Comedy, Drama]       87    41819        NaN
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   year       1000 non-null   int64
#  2   rating     1000 non-null   float64
#  3   genres     1000 non-null   object
#  4   runtime    1000 non-null   int64
#  5   votes      1000 non-null   int64
#  6   metascore  815 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %%
movies.columns
# Out:
# Index(['title', 'year', 'rating', 'genres', 'runtime', 'votes', 'metascore'], dtype='object')

# %%
movies.title.count()
# Out:
# 1000

# %%
movies.year.count()
# Out:
# 1000

# %%
movies.rating.count()
# Out:
# 1000

# %%
movies.genres.count()

# %%
movies.runtime.count()
# Out:
# 1000

# %%
movies.votes.count()
# Out:
# 1000

# %%
movies.metascore.count()
# Out:
# 815

# %%
movies.title.value_counts().head(10)
# Out:
# title
# Drishyam 2                         2
# Beauty and the Beast               2
# Drishyam                           2
# All Quiet on the Western Front     2
# The Girl with the Dragon Tattoo    2
# Scarface                           2
# Cast Away                          1
# Taken                              1
# Skyfall                            1
# The Untouchables                   1
# Name: count, dtype: int64

# %%
movies.loc[movies['title'] == "Drishyam 2"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %% [markdown]
# Verifying the movies, the 2022 version is a Hindi remake.

# %%
movies.loc[93, "title"] = "Drishyam 2 (2021)"

# %%
movies.loc[182, "title"] = "Drishyam 2 (2022)"

# %%
movies.loc[movies['title'] == "Beauty and the Beast"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %%
movies.loc[387, "title"] = "Beauty and the Beast (1991)"

# %%
movies.loc[604, "title"] = "Beauty and the Beast (1946)"

# %%
movies.loc[movies['title'] == "Drishyam"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %%
movies.loc[142, "title"] = "Drishyam (2013)"

# %%
movies.loc[192, "title"] = "Drishyam (2015)"

# %% [markdown]
# Verifying the movies, it had the same scenario as Drishyam 2.

# %%
movies.loc[movies['title'] == "All Quiet on the Western Front"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %%
movies.loc[290, "title"] = "All Quiet on the Western Front (1930)"

# %%
movies.loc[630, "title"] = "All Quiet on the Western Front (2022)"

# %%
movies.loc[movies['title'] == "The Girl with the Dragon Tattoo"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %%
movies.loc[654, "title"] = "The Girl with the Dragon Tattoo (2011)"

# %%
movies.loc[696, "title"] = "The Girl with the Dragon Tattoo (2009)"

# %% [markdown]
# The earlier movie is in Swedish, while the 2011 version is in English.

# %%
movies.loc[movies['title'] == "Scarface"]
# Out:
# Empty DataFrame
# Columns: [title, year, rating, genres, runtime, votes, metascore]
# Index: []

# %%
movies.loc[99, "title"] = "Scarface (1983)"

# %%
movies.loc[928, "title"] = "Scarface (1932)"

# %%
movies.duplicated(subset=["title", "year", "runtime"], keep='first').sum()
# Out:
# 0

# %%
pd.set_option("display.max_rows", None)
movies.year.value_counts()
# Out:
# year
# 2014    33
# 2016    32
# 2004    29
# 2013    29
# 2019    27
# 2009    25
# 2001    25
# 2012    24
# 2022    24
# 2018    23
# 2015    23
# 2017    23
# 2007    22
# 2006    22
# 1993    22
# 2003    20
# 2010    19
# 1997    19
# 2000    18
# 1999    17
# 2008    17
# 2005    15
# 2011    15
# 1995    15
# 2002    14
# 1998    13
# 1962    13
# 1994    12
# 1992    12
# 2021    12
# 1982    11
# 2020    11
# 1975    11
# 1986    11
# 1989    11
# 1987    10
# 1973    10
# 1967    10
# 1988    10
# 1990     9
# 1972     9
# 1960     9
# 1991     9
# 1957     9
# 1980     8
# 1985     8
# 1996     8
# 1984     8
# 1971     8
# 1979     8
# 1959     7
# 1940     7
# 1964     7
# 1976     7
# 1961     6
# 1948     6
# 1955     6
# 1963     6
# 1954     6
# 1983     6
# 1946     6
# 1974     6
# 1968     6
# 1966     6
# 1950     6
# 1944     5
# 1953     5
# 1952     5
# 1958     5
# 1978     5
# 1951     5
# 1939     5
# 1956     4
# 1945     4
# 1969     4
# 2023     4
# ...

# %%
movies.year.value_counts()
# Out:
# year
# 2014    33
# 2016    32
# 2004    29
# 2013    29
# 2019    27
# 2009    25
# 2001    25
# 2012    24
# 2022    24
# 2018    23
# 2015    23
# 2017    23
# 2007    22
# 2006    22
# 1993    22
# 2003    20
# 2010    19
# 1997    19
# 2000    18
# 1999    17
# 2008    17
# 2005    15
# 2011    15
# 1995    15
# 2002    14
# 1998    13
# 1962    13
# 1994    12
# 1992    12
# 2021    12
# 1982    11
# 2020    11
# 1975    11
# 1986    11
# 1989    11
# 1987    10
# 1973    10
# 1967    10
# 1988    10
# 1990     9
# 1972     9
# 1960     9
# 1991     9
# 1957     9
# 1980     8
# 1985     8
# 1996     8
# 1984     8
# 1971     8
# 1979     8
# 1959     7
# 1940     7
# 1964     7
# 1976     7
# 1961     6
# 1948     6
# 1955     6
# 1963     6
# 1954     6
# 1983     6
# 1946     6
# 1974     6
# 1968     6
# 1966     6
# 1950     6
# 1944     5
# 1953     5
# 1952     5
# 1958     5
# 1978     5
# 1951     5
# 1939     5
# 1956     4
# 1945     4
# 1969     4
# 2023     4
# ...

# %%
pd.reset_option("all")

# %%
movies.isna().sum()
# Out:
# title          0
# year           0
# rating         0
# genres         0
# runtime        0
# votes          0
# metascore    185
# dtype: int64

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                           genres  runtime    votes  metascore
# 0                        [Drama]      142  2757059       82.0
# 1                 [Crime, Drama]      175  1918435      100.0
# 2                [Comedy, Drama]       87    41819        NaN
# ...

# %%
movies['genres'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: genres
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
movies["genres"] = movies["genres"].astype('str')

# %%
movies['genres'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: genres
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                                 genres  runtime    votes  metascore
# 0                            ['Drama']      142  2757059       82.0
# 1                   ['Crime', 'Drama']      175  1918435      100.0
# ...

# %%
movies.genres = movies.genres.str[1:-1]

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                               genres  runtime    votes  metascore
# 0                            'Drama'      142  2757059       82.0
# 1                   'Crime', 'Drama'      175  1918435      100.0
# 2                  'Comedy', 'Drama'       87    41819        NaN
# ...

# %%
movies['genres'] = movies['genres'].str.replace("'", "")

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                         genres  runtime    votes  metascore
# 0                        Drama      142  2757059       82.0
# 1                 Crime, Drama      175  1918435      100.0
# 2                Comedy, Drama       87    41819        NaN
# ...

# %%
movies.describe()
# Out:
#              year      rating      runtime         votes   metascore
# count  1000.00000  1000.00000  1000.000000  1.000000e+03  815.000000
# mean   1992.16200     7.98330   125.308000  3.131757e+05   79.087117
# std      24.38763     0.27442    29.489774  3.858921e+05   11.987033
# min    1920.00000     7.60000    45.000000  2.525800e+04   33.000000
# 25%    1975.00000     7.80000   103.750000  5.733900e+04   71.000000
# 50%    2000.00000     7.90000   121.000000  1.432260e+05   80.000000
# 75%    2012.00000     8.10000   140.000000  4.390858e+05   88.000000
# max    2023.00000     9.30000   321.000000  2.757059e+06  100.000000

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                         genres  runtime    votes  metascore
# 0                        Drama      142  2757059       82.0
# 1                 Crime, Drama      175  1918435      100.0
# 2                Comedy, Drama       87    41819        NaN
# ...

# %%
bins = [1920, 1929, 1939, 1949, 1959, 1969, 1979, 1989, 1999, 2009, 2019, 2029]
labels = ["1920s", "1930s", "1940s", "1950s", "1960s", "1970s", "1980s", "1990s", "2000s", "2010s", "2020s"]
movies['decade'] = pd.cut(x = movies['year'], bins = bins, labels = labels, include_lowest = True)

# %%
movies.head(20)
# Out:
#                                                 title  year  rating
# 0                            The Shawshank Redemption  1994     9.3  \
# 1                                       The Godfather  1972     9.2
# 2                                     The Chaos Class  1975     9.2
# 3                                     The Dark Knight  2008     9.0
# 4                                    Schindler's List  1993     9.0
# 5                                        12 Angry Men  1957     9.0
# 6                               The Godfather Part II  1974     9.0
# 7       The Lord of the Rings: The Return of the King  2003     9.0
# 8                                         Mirror Game  2016     9.0
# 9                 Spider-Man: Across the Spider-Verse  2023     8.9
# 10                                       Pulp Fiction  1994     8.9
# 11                                          Inception  2010     8.8
# 12  The Lord of the Rings: The Fellowship of the Ring  2001     8.8
# ...

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                         genres  runtime    votes  metascore decade
# 0                        Drama      142  2757059       82.0  1990s
# 1                 Crime, Drama      175  1918435      100.0  1970s
# ...

# %%
movies.to_csv('movies_cleaned.csv')

# %%
movies
# Out:
#                                       title  year  rating
# 0                  The Shawshank Redemption  1994     9.3  \
# 1                             The Godfather  1972     9.2
# 2                           The Chaos Class  1975     9.2
# 3                           The Dark Knight  2008     9.0
# 4                          Schindler's List  1993     9.0
# ..                                      ...   ...     ...
# 995  Harry Potter and the Half-Blood Prince  2009     7.6
# 996                              The Others  2001     7.6
# 997                  The Godfather Part III  1990     7.6
# 998                              Inside Man  2006     7.6
# 999                          Train to Busan  2016     7.6
#
#                         genres  runtime    votes  metascore decade
# 0                        Drama      142  2757059       82.0  1990s
# 1                 Crime, Drama      175  1918435      100.0  1970s
# ...
